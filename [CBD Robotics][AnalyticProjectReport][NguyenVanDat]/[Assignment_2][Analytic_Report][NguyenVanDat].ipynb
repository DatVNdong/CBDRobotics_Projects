# %%
#Đây là bảng báo cáo phân tích file csv về movie
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
filepath = "/Users/Dat/Jupyter/Assignment_02"
filename = "tmdb_5000_movies.csv"
filePathFileName = filepath + "/" + filename
outputFile=os.path.join("/Users/Dat/Jupyter/Assignment_02/tmdb_5000_movies_cleaned.csv")
df = pd.read_csv(filePathFileName)

# %%
df = df.rename(columns={'production_countries': 'countries'})
df = df.rename(columns={'production_companies': 'companies'})

# %%
df.columns
#Như ta đã thấy tập dữ liệu bao gồm các cột ở phía dưới, có những cột quan trọng là revenue, vote_average, budget, countries
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'companies', 'countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "US", "name": "United States of America"}', 'USA')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "GB", "name": "United Kingdom"}', 'UK')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "DE", "name": "Germany"}', 'Germany')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CA", "name": "Canada"}', 'Canada')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "FR", "name": "France"}', 'France')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AU", "name": "Australia"}', 'Australia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IN", "name": "India"}', 'India')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "JP", "name": "Japan"}', 'Japan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CN", "name": "China"}', 'China')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "HK", "name": "Hong Kong"}', 'Hong Kong')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "KR", "name": "South Korea"}', 'South Korea')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "ES", "name": "Spain"}', 'Spain')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "NZ", "name": "New Zealand"}', 'New Zealand')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "RU", "name": "Russia"}', 'Russia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IT", "name": "Italy"}', 'Italy')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CZ", "name": "Czech Republic"}', 'Czech')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "HU", "name": "Hungary"}', 'Hungary')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "NL", "name": "Netherlands"}', 'Netherlands')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "NO", "name": "Norway"}', 'Norway')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "KH", "name": "Cambodia"}', 'Cambodia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AE", "name": "United Arab Emirates"}', 'UAE')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CH", "name": "Switzerland"}', 'Switzerland')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BE", "name": "Belgium"}', 'Belgium')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "RO", "name": "Romania"}', 'Romania')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IE", "name": "Ireland"}', 'Ireland')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "LU", "name": "Luxembourg"}', 'Luxembourg')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BO", "name": "Bolivia"}', 'Bolivia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "TH", "name": "Thailand"}', 'Thailand')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "LB", "name": "Lebanon"}', 'Lebanon')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BG", "name": "Bulgaria"}', 'Bulgaria')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "MX", "name": "Mexico"}', 'Mexico')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "SE", "name": "Sweden"}', 'Sweden')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IL", "name": "Israel"}', 'Israel')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "PK", "name": "Pakistan"}', 'Pakistan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CM", "name": "Cameroon"}', 'Cameroon')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "ZA", "name": "South Africa"}', 'South Africa')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "KZ", "name": "Kazakhstan"}', 'Kazakhstan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "EG", "name": "Egypt"}', 'Egypt')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BR", "name": "Brazil"}', 'Brazil')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "KE", "name": "Kenya"}', 'Kenya')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "PE", "name": "Peru"}', 'Peru')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IS", "name": "Iceland"}', 'Iceland')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "IR", "name": "Iran"}', 'Iran')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AR", "name": "Argentina"}', 'Argentina')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "GR", "name": "Greece"}', 'Greece')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "UA", "name": "Ukraine"}', 'Ukraine')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "SK", "name": "Slovakia"}', 'Slovakia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "DK", "name": "Denmark"}', 'Denmark')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "PL", "name": "Poland"}', 'Poland')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "TW", "name": "Taiwan"}', 'Taiwan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "FI", "name": "Finland"}', 'Finland')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "MT", "name": "Malta"}', 'Malta')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "MA", "name": "Morocco"}', 'Morocco')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AT", "name": "Austria"}', 'Austria')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AW", "name": "Aruba"}', 'Aruba')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BA", "name": "Bosnia and Herzegovina"}', 'B&H')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BS", "name": "Bahamas"}', 'Bahamas')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "BT", "name": "Bhutan"}', 'Bhutan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CY", "name": "Cyprus"}', 'Cyprus')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "JO", "name": "Jordan"}', 'Jordan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "DO", "name": "Dominican Republic"}', 'Dominican Republic')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "DZ", "name": "Algeria"}', 'Algeria')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "EC", "name": "Ecuador"}', 'Ecuador')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CO", "name": "Colombia"}', 'Colombia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "FJ", "name": "Fiji"}', 'Fiji')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "GP", "name": "Guadaloupe"}', 'Guadaloupe')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "GY", "name": "Guyana"}', 'Guyana')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "ID", "name": "Indonesia"}', 'Indonesia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "JM", "name": "Jamaica"}', 'Jamaica')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "PA", "name": "Panama"}', 'Panama')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "DM", "name": "Dominica"}', 'Dominica')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "KG", "name": "Kyrgyz Republic"}', 'Kyrgyz')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "LY", "name": "Libyan Arab Jamahiriya"}', 'Libyan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "MY", "name": "Malaysia"}', 'Malaysia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "PH", "name": "Philippines"}', 'Philippines')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "SG", "name": "Singapore"}', 'Singapore')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "SI", "name": "Slovenia"}', 'Slovenia')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "TR", "name": "Turkey"}', 'Turkey')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "AF", "name": "Afghanistan"}', 'Afghanistan')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "NG", "name": "Nigeria"}', 'Nigeria')
df['countries'] = df['countries'].str.replace('{"iso_3166_1": "CL", "name": "Chile"}', 'Chile')

# %%
def ct(data_fr):
    revenue_sum = 0
    for row in data_fr.itertuples():
        revenue_sum += row.revenue
    return revenue_sum
raw_data = {'Country': ['USA','UK','Germany','Canada','France','Australia','India','Japan','China','Hong Kong','South Korea','Spain','New Zealand','Russia','Italy','Czech','Hungary','Netherlands','Norway','Cambodia','UAE','Switzerland','Belgium','Romania','Ireland','Luxembourg','Bolivia','Thailand','Lebanon','Bulgaria','Mexico','Sweden','Israel','Pakistan','Cameroon','South Africa','Kazakhstan','Egypt','Brazil','Kenya','Peru','Iceland','Iran','Argentina','Greece','Ukraine'
                        ,'Slovakia','Denmark','Poland','Taiwan','Finland','Malta','Morocco','Austria','Aruba','Bosnia and Herzegovina','Bahamas','Bhutan','Cyprus','Jordan','Dominican Republic','Algeria','Ecuador','Colombia','Fiji','Guadaloupe','Guyana','Indonesia','Jamaica','Panama','Dominica','Kyrgyz','Libyan','Malaysia','Philippines','Singapore','Slovenia','Turkey','Afghanistan','Nigeria','Chile'], 
        'Total_Revenue': [ct(df[df['countries'].str.contains('USA')]), ct(df[df['countries'].str.contains('UK')]), ct(df[df['countries'].str.contains('Germany')]), ct(df[df['countries'].str.contains('Canada')]), ct(df[df['countries'].str.contains('France')]), ct(df[df['countries'].str.contains('Australia')]), ct(df[df['countries'].str.contains('India')]), ct(df[df['countries'].str.contains('Japan')]), ct(df[df['countries'].str.contains('China')])
                             , ct(df[df['countries'].str.contains('Hong Kong')]), ct(df[df['countries'].str.contains('South Korea')]), ct(df[df['countries'].str.contains('Spain')]), ct(df[df['countries'].str.contains('New Zealand')]), ct(df[df['countries'].str.contains('Russia')]), ct(df[df['countries'].str.contains('Italy')]), ct(df[df['countries'].str.contains('Czech')]), ct(df[df['countries'].str.contains('Hungary')]), ct(df[df['countries'].str.contains('Netherlands')])
                             , ct(df[df['countries'].str.contains('Norway')]), ct(df[df['countries'].str.contains('Cambodia')]), ct(df[df['countries'].str.contains('UAE')]), ct(df[df['countries'].str.contains('Switzerland')]), ct(df[df['countries'].str.contains('Belgium')]), ct(df[df['countries'].str.contains('Romania')]), ct(df[df['countries'].str.contains('Ireland')]), ct(df[df['countries'].str.contains('Luxembourg')]), ct(df[df['countries'].str.contains('Bolivia')])
                             , ct(df[df['countries'].str.contains('Thailand')]), ct(df[df['countries'].str.contains('Lebanon')]), ct(df[df['countries'].str.contains('Bulgaria')]), ct(df[df['countries'].str.contains('Mexico')]), ct(df[df['countries'].str.contains('Sweden')]), ct(df[df['countries'].str.contains('Israel')]), ct(df[df['countries'].str.contains('Pakistan')]), ct(df[df['countries'].str.contains('Cameroon')]), ct(df[df['countries'].str.contains('South Africa')])
                             , ct(df[df['countries'].str.contains('Kazakhstan')]), ct(df[df['countries'].str.contains('Egypt')]), ct(df[df['countries'].str.contains('Brazil')]), ct(df[df['countries'].str.contains('Kenya')]), ct(df[df['countries'].str.contains('Peru')]), ct(df[df['countries'].str.contains('Iceland')]), ct(df[df['countries'].str.contains('Iran')]), ct(df[df['countries'].str.contains('Argentina')]), ct(df[df['countries'].str.contains('Greece')])
                             , ct(df[df['countries'].str.contains('Ukraine')]), ct(df[df['countries'].str.contains('Slovakia')]), ct(df[df['countries'].str.contains('Denmark')]), ct(df[df['countries'].str.contains('Poland')]), ct(df[df['countries'].str.contains('Taiwan')]), ct(df[df['countries'].str.contains('Finland')]), ct(df[df['countries'].str.contains('Malta')]), ct(df[df['countries'].str.contains('Morocco')]), ct(df[df['countries'].str.contains('Austria')])
                             , ct(df[df['countries'].str.contains('Aruba')]), ct(df[df['countries'].str.contains('B&H')]), ct(df[df['countries'].str.contains('Bahamas')]), ct(df[df['countries'].str.contains('Bhutan')]), ct(df[df['countries'].str.contains('Cyprus')]), ct(df[df['countries'].str.contains('Jordan')]), ct(df[df['countries'].str.contains('Dominican Republic')]), ct(df[df['countries'].str.contains('Algeria')]), ct(df[df['countries'].str.contains('Ecuador')])
                             , ct(df[df['countries'].str.contains('Colombia')]), ct(df[df['countries'].str.contains('Fiji')]), ct(df[df['countries'].str.contains('Guadaloupe')]), ct(df[df['countries'].str.contains('Guyana')]), ct(df[df['countries'].str.contains('Indonesia')]), ct(df[df['countries'].str.contains('Jamaica')]), ct(df[df['countries'].str.contains('Panama')]), ct(df[df['countries'].str.contains('Dominica')]), ct(df[df['countries'].str.contains('Kyrgyz')])
                             , ct(df[df['countries'].str.contains('Libyan')]), ct(df[df['countries'].str.contains('Malaysia')]), ct(df[df['countries'].str.contains('Philippines')]), ct(df[df['countries'].str.contains('Singapore')]), ct(df[df['countries'].str.contains('Slovenia')]), ct(df[df['countries'].str.contains('Turkey')]), ct(df[df['countries'].str.contains('Afghanistan')]), ct(df[df['countries'].str.contains('Nigeria')]), ct(df[df['countries'].str.contains('Chile')])
                         ]}
df2 = pd.DataFrame(raw_data, columns = ['Country', 'Total_Revenue'])

# %%
df2 = df2.sort_values(by=['Total_Revenue'], ascending=False)

# %%
ax = df2[['Total_Revenue']].plot(x = df2['Country'], kind='bar', title ="Revenue influence", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel("Country", fontsize=12)
ax.set_ylabel("Revenue", fontsize=12)
plt.show()

# %%
#Trả lời câu hỏi thứ 1: What areas have the most influence on revenue?
#Nhìn vào đồ thị vẽ ở trên thì ta có thể thấy có 1 sự vượt trội về revenue ở khu vực USA, tiếp đến là khu vực các nước châu Âu như 
#UK, Germany, France cùng với 1 số nước phát triển ở Châu Á như Japan, China. Các nước đang phát triển thì không ảnh hưởng nhiều đến revenue
#Đây cũng là điều dễ hiểu vì sự vượt trội về kỹ xảo lẫn nội dung của các phim Hollywood chính là thứ mang lại revenue khủng cho các vụ phim

# %%
df['genres'] = df['genres'].str.replace('{"id": 18, "name": "Drama"}', 'Drama')
df['genres'] = df['genres'].str.replace('{"id": 35, "name": "Comedy"}', 'Comedy')
df['genres'] = df['genres'].str.replace('{"id": 10749, "name": "Romance"}', 'Romance')
df['genres'] = df['genres'].str.replace('{"id": 27, "name": "Horror"}', 'Horror')
df['genres'] = df['genres'].str.replace('{"id": 53, "name": "Thriller"}', 'Thriller')
df['genres'] = df['genres'].str.replace('{"id": 99, "name": "Documentary"}', 'Documentary')
df['genres'] = df['genres'].str.replace('{"id": 36, "name": "History"}', 'History')
df['genres'] = df['genres'].str.replace('{"id": 28, "name": "Action"}', 'Action')
df['genres'] = df['genres'].str.replace('{"id": 16, "name": "Animation"}', 'Animation')
df['genres'] = df['genres'].str.replace('{"id": 10751, "name": "Family"}', 'Family')
df['genres'] = df['genres'].str.replace('{"id": 10402, "name": "Music"}', 'Music')
df['genres'] = df['genres'].str.replace('{"id": 12, "name": "Adventure"}', 'Adventure')
df['genres'] = df['genres'].str.replace('{"id": 9648, "name": "Mystery"}', 'Mystery')
df['genres'] = df['genres'].str.replace('{"id": 878, "name": "Science Fiction"}', 'Science Fiction')
df['genres'] = df['genres'].str.replace('{"id": 14, "name": "Fantasy"}', 'Fantasy')
df['genres'] = df['genres'].str.replace('{"id": 10752, "name": "War"}', 'War')
df['genres'] = df['genres'].str.replace('{"id": 80, "name": "Crime"}', 'Crime')
df['genres'] = df['genres'].str.replace('{"id": 37, "name": "Western"}', 'Western')
df['genres'] = df['genres'].str.replace('{"id": 10769, "name": "Foreign"}', 'Foreign')

# %%
def avs(dt_fr):
    aver_score = 0
    count = 0
    for row in dt_fr.itertuples():
        aver_score += row.vote_average
        count += 1
    return float("{0:.2f}".format(aver_score/count)) 
raw_data2 = {'Genres': ['Drama','Comedy','Romance','Horror','Thriller','Documentary','History','Action','Animation','Family','Music','Adventure','Mystery','Science Fiction','Fantasy','War','Crime','Western','Foreign'], 
        'Total_Revenue': [ct(df[df['genres'].str.contains('Drama')]), ct(df[df['genres'].str.contains('Comedy')]), ct(df[df['genres'].str.contains('Romance')]), ct(df[df['genres'].str.contains('Horror')]), ct(df[df['genres'].str.contains('Thriller')]), ct(df[df['genres'].str.contains('Documentary')])
                             , ct(df[df['genres'].str.contains('History')]), ct(df[df['genres'].str.contains('Action')]), ct(df[df['genres'].str.contains('Animation')]), ct(df[df['genres'].str.contains('Family')]), ct(df[df['genres'].str.contains('Music')]), ct(df[df['genres'].str.contains('Adventure')])
                             , ct(df[df['genres'].str.contains('Mystery')]), ct(df[df['genres'].str.contains('Science Fiction')]), ct(df[df['genres'].str.contains('Fantasy')]), ct(df[df['genres'].str.contains('War')]), ct(df[df['genres'].str.contains('Crime')]), ct(df[df['genres'].str.contains('Western')])
                             , ct(df[df['genres'].str.contains('Foreign')])], 
        'Average_Score': [
            avs(df[df['genres'].str.contains('Drama')]), avs(df[df['genres'].str.contains('Comedy')]), avs(df[df['genres'].str.contains('Romance')]), avs(df[df['genres'].str.contains('Horror')]), avs(df[df['genres'].str.contains('Thriller')]), avs(df[df['genres'].str.contains('Documentary')])
                , avs(df[df['genres'].str.contains('History')]), avs(df[df['genres'].str.contains('Action')]), avs(df[df['genres'].str.contains('Animation')]), avs(df[df['genres'].str.contains('Family')]), avs(df[df['genres'].str.contains('Music')]), avs(df[df['genres'].str.contains('Adventure')])
                , avs(df[df['genres'].str.contains('Mystery')]), avs(df[df['genres'].str.contains('Science Fiction')]), avs(df[df['genres'].str.contains('Fantasy')]), avs(df[df['genres'].str.contains('War')]), avs(df[df['genres'].str.contains('Crime')]), avs(df[df['genres'].str.contains('Western')])
                , avs(df[df['genres'].str.contains('Foreign')])
        ]}
df3 = pd.DataFrame(raw_data2, columns = ['Genres', 'Total_Revenue','Average_Score'])

# %%
df3 = df3.sort_values(by=['Total_Revenue'], ascending=False)

# %%
ax = df3.set_index('Average_Score')['Total_Revenue'].plot(style='o')
def label_point(x, y, gen, ax):
    a = pd.concat({'x': x, 'y': y, 'val': gen}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']))
label_point(df3.Average_Score, df3.Total_Revenue, df3.Genres, ax)

# %%
#Trả lời câu hỏi thứ 2: How is a movie’s revenue and average score affected by its genre?
#Nhìn vào Scatter Plot ở trên, với trục X là Average_Score, trục Y là Total_Revenue thì ta có thể thấy rằng các bộ phim có chủ đề mang tính giải
#trí như Action, Adventure, Comedy, Thriller hay Drama thì sẽ có mức điểm chấm ở mức trên trung bình, tiệm cận khá, nhưng bù lại sẽ mang về revenue khủng
#Đặc biệt là với dòng phim Action, Adventure. Rất dễ hiểu vì với những bộ phim thế này thì NSX sẽ rất tự do trong việc sáng tạo và vẽ nên những thước phim 
#hùng vĩ, đẹp đẽ, nội dung có thể không hay nhưng ở mức vừa phải và mang lại lợi nhuận khủng. 
#Top đầu về điểm có lẽ là những bộ phim nội dung sâu sắc về History, Documentary, Music, Animation. Với nội dung tốt tuy nhiên revenue lại không sánh bằng
#Cuối cùng là dòng phim Horror, kén người xem và khó có thể tạo ra nội dung tốt. Chính vì vậy mà cả Score lẫn Revenue đều khá thấp. Cũng phải thôi vì đâu phải 
#ai cũng thích xem phim "đau tim" kiểu này

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
def mr(mon):
    sum_reve = 0
    count = 0
    for row in df.itertuples():
        if(int(mon) is row.release_date.month):
            sum_reve += row.revenue
            count += 1
    return sum_reve/count
raw_data3 = {'Month': ['01','02','03','04','05','06','07','08','09','10','11','12'], 
        'Average_Revenue': [mr('01'), mr('02'), mr('03'), mr('04'), mr('05'), mr('06'), mr('07'), mr('08'), mr('09'), mr('10'), mr('11'), mr('12')]}
df4 = pd.DataFrame(raw_data3, columns = ['Month', 'Average_Revenue'])

# %%
df4.plot.bar(x='Month', y='Average_Revenue')

# %%
#Trả lời câu hỏi thứ 3: What influence does release date have on revenue?
#Bảng Graph Bar Plot ở trên đã group Average_Revenue theo các tháng. 1 điều dễ thấy đó là hầu như các phim có revenue khủng đều nằm trong giai đoạn mùa hè và mùa đông
#Lúc mà có các kì nghỉ. Lượng người xem sẽ tăng đột biến. Đặc biệt vào giai đoạn tháng 05, 06 khi các kỳ thi đã xong. Không phải vô lý do mà các phim bom tấn hầu như
#đều được chiếu vào trong giai đoạn này
#Các thời gian còn lại thì NSX phim ít chú trọng đầu tư, đặc biệt vào tháng 1 lúc chuyển giao năm mới, công việc tấp nập khiến lượng doanh thu giảm rõ rệt.

# %%
#Vì kiến thức hạn hẹp nên em chỉ có thể làm được như thế này. Mong thầy góp ý để em rút thêm kinh nghiệm và có bản báo cáo hoàn chỉnh tốt hơn! Em xin cảm ơn!
